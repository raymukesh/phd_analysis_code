# %%
import ee
import geemap
import os

# %%
Map = geemap.Map()
Map
# Out:
# Map(center=[40, -100], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(T…

# %%
site = ee.FeatureCollection('users/Introduction/study_area')
Map.addLayer(site, {}, "study_area")

# %%
# Calculate Long Term Rainfall Average

# CHIRPS data comes as Pentad
modis_day = ee.ImageCollection('MODIS/006/MOD13Q1') ## 16 Day Composite


# Long Period Average (LPA) should by 30 years or more

# Center to site
Map.centerObject(site, 9)

# List of 30 years
lpaYears = ee.List.sequence(2020, 2020)
months = ee.List.sequence(1, 12)

# # Introducting calendarRange()
# julyImages = chirps
#   .filter(ee.Filter.calendarRange(7, 7, 'month'))
# print(julyImages)

# Define time range
startyear = 2001
endyear = 2021

# Set date in ee date format
startdate = ee.Date.fromYMD(startyear,1,1)
enddate = ee.Date.fromYMD(endyear+1,12,31)

 
# create list for years
years = range(startyear,endyear);
 
# make a list with months
months = range(1,13)

#Filter to select Precipitation band
temperature = modis_day.filterDate(startdate, enddate).sort('system:time_start', False).select("NDVI")

# Map over the years and create a monthly totals collection

# calculate the monthly Sum
def MonthlyMean(imageCollection):
    mylist = ee.List([])
    for y in years:
        for m in months:
            w = imageCollection.filter(ee.Filter.calendarRange(y, y, 'year')).filter(ee.Filter.calendarRange(m, m, 'month')).mean()
            #mylist = mylist.add(w)
            mylist = mylist.add(w.set('year', y).set('month', m).set('date', ee.Date.fromYMD(y,m,1)).set('system:time_start',ee.Date.fromYMD(y,m,1)))
    return ee.ImageCollection.fromImages(mylist)


# run the calcMonthlyMean function
monthlyChirps = ee.ImageCollection(MonthlyMean(temperature))


print("coll", monthlyChirps.first().getInfo())
# Out:
# coll {'type': 'Image', 'bands': [{'id': 'NDVI', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -32768, 'max': 32767}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}], 'properties': {'date': {'type': 'Date', 'value': 978307200000}, 'system:time_start': {'type': 'Date', 'value': 978307200000}, 'month': 1, 'year': 2001, 'system:index': '0'}}

# %%
image_ids = monthlyChirps.aggregate_array('system:index').getInfo()
print('Total images: ', len(image_ids))
print(monthlyChirps.first().getInfo())
# Out:
# Total images:  240
# {'type': 'Image', 'bands': [{'id': 'NDVI', 'data_type': {'type': 'PixelType', 'precision': 'double', 'min': -32768, 'max': 32767}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}], 'properties': {'date': {'type': 'Date', 'value': 978307200000}, 'system:time_start': {'type': 'Date', 'value': 978307200000}, 'month': 1, 'year': 2001, 'system:index': '0'}}

# %%
out_dir = os.path.join(os.path.expanduser('~'), 'Downloads/ndvi_stack16_terra')
geemap.ee_export_image_collection(monthlyChirps, out_dir = out_dir, scale = 250, region= site.geometry(), file_per_band= False)
# Out:
# Total number of images: 240
#
# Exporting 1/240: 0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/560147a6b938f5a94651c177cb60f026-ee1cd2ff71b04eac2c5d5e7b942ea7a6:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\0.tif
#
#
# Exporting 2/240: 1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/cda70b389d902048eaf5e1639b865ed3-f6c3323039dc3c38a9f20c6df24ff259:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\1.tif
#
#
# Exporting 3/240: 2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/03b55eb530f52bfdc102508284f0349b-188aebd9a207a519fc696d5de48280ea:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\2.tif
#
#
# Exporting 4/240: 3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3000e352ab02a257f2788d74e6f8d9c3-15dd6c6cf59e6fba5b088e109540932f:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\3.tif
#
#
# Exporting 5/240: 4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8ded3a5ebf0ffa287d20bc2eca9c6fe0-bde5addd100d8fb70970e3d54a198977:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\4.tif
#
#
# Exporting 6/240: 5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/24753faed43e0dfb91b0468cddfa590f-87a6f1cd234b77bb504382a9fae532db:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\5.tif
#
#
# Exporting 7/240: 6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a478561dc40422594355f8bf1ef3aff7-4a01f8dd843781f5281e4984ceca9dd7:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\6.tif
#
#
# Exporting 8/240: 7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e7e6b13baae0b30c7bda647455769e78-e23957ed404c6252910c4dabeaf86c8d:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\7.tif
#
#
# Exporting 9/240: 8.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/808947e10b06c2dfa8e35dfc5fd5f866-1fa6e84ee94d9dcacbec65a10bc26469:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\8.tif
#
#
# Exporting 10/240: 9.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0c6cf330800f9e3903edc056b2a96c07-089c7285a57a5d45c897eb6ed5cbbaf3:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\9.tif
#
#
# Exporting 11/240: 10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b45fd54fad5cb690a34172759d2fe06a-a3880873bc14d68d740294c72d4e56b2:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\10.tif
#
#
# Exporting 12/240: 11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a9a6ec7299f191259e4d3c953d340877-937f1c551163e9856ba0def8f6b74acb:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\11.tif
#
#
# Exporting 13/240: 12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/338ec6a61daee38a2e5bb48360ba6a91-b91bdbbd9c866bbfe69351f9a1457ddb:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\12.tif
#
#
# Exporting 14/240: 13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c784e7de5a22dce111cc7815b9742db3-8678c70998ad1056d08f30f47a5df387:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\13.tif
#
#
# Exporting 15/240: 14.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f6e8f13596468dc25bf4d0db8476b6bb-bf4c740138eddbd035448fbe0f4befbb:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\14.tif
#
#
# Exporting 16/240: 15.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/bddd3f927e6381e0a391dc12e25f0309-a7521c9c5c589edbb1b6bdb7409c2753:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\15.tif
#
#
# Exporting 17/240: 16.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/eda538787ff075ef5513cdec96a2f5aa-c02c09e05dd4b5048221f784d55ea012:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\16.tif
#
#
# Exporting 18/240: 17.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3c6ea1334841a5c91370120b163947b2-dbcf4642bca3c6278c1b54ed50450e48:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\17.tif
#
#
# Exporting 19/240: 18.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f2b47357e3b30d97bfee5983a72ef1fe-3d05dcf4ecacec708cca266ad1a4ec20:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\18.tif
#
#
# Exporting 20/240: 19.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e6be450ccd859b2d76c9a56d738fe654-20991ee1e2c50045a25b2a3aa8b46b08:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\19.tif
#
#
# Exporting 21/240: 20.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/2ffa6ee407e9fe58ea2e05af4590a2ad-4fd045c64b1a5fa9e9ab169a466f37e7:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\20.tif
#
#
# Exporting 22/240: 21.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b40b57242def09df971e541e90d9f9e9-469a4f47c5fc3ef09ec33f8bbad297c8:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\21.tif
#
#
# Exporting 23/240: 22.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9dea0efbff6c4c9575536751f75d3af2-6d780bb164f27ad700460d1006aef533:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\22.tif
#
#
# Exporting 24/240: 23.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/72cb8fcfbce01cc5f418de0b08dce989-f0f2e1df6f565ddf44d6488ce0b4c365:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\23.tif
#
#
# Exporting 25/240: 24.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ecefbbde69173fbc2840735065ae4ccf-e27b2b7018c2c69b09020e39921fa296:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\24.tif
#
#
# Exporting 26/240: 25.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8793b28c0e62c043b95c9ed88368fc78-b65eebf3cad30c110e848957c93cd478:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\25.tif
#
#
# Exporting 27/240: 26.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/acdee60d0229105f486de131f3fc99e5-0252cf065c15a100edddb71b64a36eed:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\26.tif
#
#
# Exporting 28/240: 27.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/46388c722e0f5cf62dce1786a1af465c-0764d1421b20965d6544e28dc111c05f:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\27.tif
#
#
# Exporting 29/240: 28.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/2b45e1cfc275f29f3a9d9c777af858b3-67de7460952c38aa95ded30f00dafc55:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\28.tif
#
#
# Exporting 30/240: 29.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e43ddca2efdd93fee956fe8aec7adcd1-4292f0521a9e5de1a2505067d7d91b10:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\29.tif
#
#
# Exporting 31/240: 30.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f9fe062f3273c888eb1f00f174cdf3d5-49dbaaa3fd7baab5a43fa819821a26be:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\30.tif
#
#
# Exporting 32/240: 31.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/05e17578ef489a7c021104c64a38ff2d-4f068fe2a065f5b97efbb728a5adc0b2:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\31.tif
#
#
# Exporting 33/240: 32.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/919f76ed774e9f1c70c0ffba4f191a24-e95b542092797ca2befe83da50ad4740:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\32.tif
#
#
# Exporting 34/240: 33.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9c645072b9dc8210cf78cc160beedd74-d5a0cab7b21c5ab4e7f7738a6a85c0d3:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\33.tif
#
#
# Exporting 35/240: 34.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3fafaa2d2fc4516f90d48ee1ffd74779-53600cd5ced9df2ac318a961994533bf:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\34.tif
#
#
# Exporting 36/240: 35.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/77c9cd9bde87be6cec8f432bec346395-9562c59b4d68eda7f3f1cb420ef7c853:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\35.tif
#
#
# Exporting 37/240: 36.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/467402778cea9c7352f08dcf01cb511c-8080f0b6aefc9009924f4f587c1cd464:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\36.tif
#
#
# Exporting 38/240: 37.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/871e31665d0f7f5af0ef7cd6a4a00851-22827a0a3b8049fd9e3ffee18cf917ab:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\37.tif
#
#
# Exporting 39/240: 38.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f763b2751159b44ea4087dab89dd59ae-d0ba649bd5875314ad0c5c68efef2dae:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\38.tif
#
#
# Exporting 40/240: 39.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/592ac876e5220d07f55614f3ec2fada4-a9b353bcaa92c42f2cdf72b5e3eca302:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\39.tif
#
#
# Exporting 41/240: 40.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4be214e6491232a3eb3065bc5613b2ad-5bd0977e7e43573f0aa5e61c92a6ad2a:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\40.tif
#
#
# Exporting 42/240: 41.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4abae928c626577955cd6cbbdfe31935-3c044a935376194d9e61c4b2b8708656:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\41.tif
#
#
# Exporting 43/240: 42.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/2c94e3832dbab9c4b77e3a3ca47467c6-b30489984b5459870c2273b220234ad8:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\42.tif
#
#
# Exporting 44/240: 43.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7e23ae94f3e15d924af40aa25bd562a1-820f3981d2838b5f4f25a3e962d1c920:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\43.tif
#
#
# Exporting 45/240: 44.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/242076f030bf5d028c813fb838d58354-81b6d240dc63e1de4195a058273f5c9a:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\44.tif
#
#
# Exporting 46/240: 45.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0a6ea98ad9d774c971d33bbb1506fb6b-7ff201df6042d48eb45ccc9dc810c2c9:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\45.tif
#
#
# Exporting 47/240: 46.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ecd01c4ae728dcd8ef8a2d2c2fb828fb-ec06949559322f26b8f38753fc7144fa:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\46.tif
#
#
# Exporting 48/240: 47.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/47864c2b66331b87073fa9c664a4d074-6a5f655ee57fd32380098ad48642cbac:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\47.tif
#
#
# Exporting 49/240: 48.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/92c2434d745b29834ba3b5ef7c07e948-3ddf41044aad4f77d6a9ac29bb156a33:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\48.tif
#
#
# Exporting 50/240: 49.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ee436e29b0a16ae6a560d543c99f19aa-8a3d653cc61a6f5f546ed15a1e4bcd30:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\49.tif
#
#
# Exporting 51/240: 50.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b3ca7bca17a3cff33743b3340464253b-0d166d75ea448bcb4a7062949a3cdff3:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\50.tif
#
#
# Exporting 52/240: 51.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a0f0603f9cdb1f1496fdacb8e7cd411d-a41548e15738d16de175dd1c76099d8a:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\51.tif
#
#
# Exporting 53/240: 52.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5fe22e1e3837d8064329b9dfae38ad63-0fdec4e2d16a1ed01d2e40c692ce789d:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\52.tif
#
#
# Exporting 54/240: 53.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f7ddb48efa638caec5f4e559433f2b40-14abcc57ca4c01933bc06134aa8d667e:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\53.tif
#
#
# Exporting 55/240: 54.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a5dca3bdf1a8bd1da7a9541de2ed7282-bd97decc5e72f125defa05bc4593c91a:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\54.tif
#
#
# Exporting 56/240: 55.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/aaf9e41d9bf256aaa296f47f68eced0b-b9629c3463eddc85a841a109e6b303de:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\55.tif
#
#
# Exporting 57/240: 56.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f0bc9769165e66f121b71625bc363f1e-c176b72300dfd10ba27fca109b79e0df:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\56.tif
#
#
# Exporting 58/240: 57.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/fc15a8325c5bb1c824975456db0edbdf-118318dd99b0845717bc48641fb39869:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\57.tif
#
#
# Exporting 59/240: 58.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/03299384d0fbdc422f30c6eae306bef1-3d1480db296c0247b1e69fce7c0dc11b:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\58.tif
#
#
# Exporting 60/240: 59.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/05d0b9222168209f29ff525f1c77c69c-08233d662d4b1d6743c19cdc0bbc3d65:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\59.tif
#
#
# Exporting 61/240: 60.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/bd24e0eec60fd6fd48fcc42673f00c6b-9ef1070e30fd82c813b118cd6bab2742:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\60.tif
#
#
# Exporting 62/240: 61.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/992a7bd92bbb888f60d99082177760af-b3219c206acbcfe27f0488f8e2721e35:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\61.tif
#
#
# Exporting 63/240: 62.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/72cd1dd50627197e29fbda022171a67e-d5a00adddaee0665ef5ff1d5497a7c3e:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\62.tif
#
#
# Exporting 64/240: 63.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/12b0ecd1e70a0eb118fdee7ebdd0d237-868b3fc7050ac5f6c09fbb8266d07eb2:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\63.tif
#
#
# Exporting 65/240: 64.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/cecb6abf108103f95ad748b9a1492354-ea3f5ce70010748b38bfdfe307750b2d:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\64.tif
#
#
# Exporting 66/240: 65.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/54ec5c471dbb69fcbfffb85bae54166a-994defdb7d219f92bc644b1b2031c391:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\65.tif
#
#
# Exporting 67/240: 66.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f3c4076989422338319b7edaafa9a4e4-3d5ace9b80e43fe11c8179aad2d4c121:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\66.tif
#
#
# Exporting 68/240: 67.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/35a8123082b546c9ad9217987f7f0a89-773d06469ac61ab3c28a5cad7a8dcb42:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\67.tif
#
#
# Exporting 69/240: 68.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7146c351bf4695ed315d7de90f92d2d1-366fc4427b13cc53a5e954af78596b22:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\68.tif
#
#
# Exporting 70/240: 69.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9d6eae1dc49dbacdf01283472692daf9-22f39856e12c26c9c194a510fb92cd16:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\69.tif
#
#
# Exporting 71/240: 70.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5a7570fece9b6d02dfaaed87e8008f96-8717f89323192c86d2cb7ac7b03c01a8:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\70.tif
#
#
# Exporting 72/240: 71.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1339421c12ebab7ac477b7535ae47e6c-fd1a162a41d9c109ec3a0d3cba9d7bf9:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\71.tif
#
#
# Exporting 73/240: 72.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/99ce33e5f775683ec010c8f65873d73f-2fe1a061ecf2bd6c18b3f0aa03c12724:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\72.tif
#
#
# Exporting 74/240: 73.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a275f803f3ece7d593630e976abb5b6b-5a1fcdeeaf466789674602e214dc38cb:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\73.tif
#
#
# Exporting 75/240: 74.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9887599cdbef5600b6c9fe473ba3d80b-b83801b3f2c2a98af02407da255f3499:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\74.tif
#
#
# Exporting 76/240: 75.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1a7cee02d78a59466b89b77a7ad530cc-eacf55588e3cac898933f733b680a549:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\75.tif
#
#
# Exporting 77/240: 76.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6316927e46ad14e54a3090d7c2a04b25-02301eede0c81df9add3f7afe3036442:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\76.tif
#
#
# Exporting 78/240: 77.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c46984d5a9004327fb91e925e0ad557e-94759b0ccb1ac9a43d3725e0accace24:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\77.tif
#
#
# Exporting 79/240: 78.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/13ff58ac2f331ed0d45d30ed4ed0fa54-1cd4286b9f5d4a916b7e9b49c5da7d9a:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\78.tif
#
#
# Exporting 80/240: 79.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c692dab9106cd5876ce24aa2f1fb6e31-91d2d34e0eb240c1dff08ae47377d720:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\79.tif
#
#
# Exporting 81/240: 80.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b19e27262961df68332c4a18128ad00f-3066f680473dddf1aac4e9dbcbe28114:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\80.tif
#
#
# Exporting 82/240: 81.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3c0e86b79d14f3d571db097c1b2a3e4e-a8139116d2139709abef0ee0d6c4968b:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\81.tif
#
#
# Exporting 83/240: 82.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/689edb57dbe9e7ec663ecbf9e4790e12-4390863474967e99e2111e904bab7f97:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\82.tif
#
#
# Exporting 84/240: 83.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c370c564bc6d4e81dda96596efb06d08-ee0e27c9a76fbd9a378a42f5e7ef39bc:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\83.tif
#
#
# Exporting 85/240: 84.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/bdd43318cea92b0c7b17d01d07a1b993-88d7a155203050dda093635c0a77a2b1:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\84.tif
#
#
# Exporting 86/240: 85.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/dadaf42191e5853d2f9ed8c69f6c86da-a9e5e8eb3570e804ba03506453178575:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\85.tif
#
#
# Exporting 87/240: 86.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/997cdfc63dd4e65b7c45b9bb9e8e9ed1-9afc78c949ae00a22072492e248a182b:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\86.tif
#
#
# Exporting 88/240: 87.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/be45220ad05cda45c7d92e5822af7f75-310494c2fec12c0fc93c2f5e50d18071:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\87.tif
#
#
# Exporting 89/240: 88.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/19aa7c9a21fd84d5dad19ce1098de179-22c610958028251bf100275065daccd1:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\88.tif
#
#
# Exporting 90/240: 89.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/879d847975fdd681c75f1a18340bbd36-be88d4387a4c0acedaf4c79d624f89ce:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\89.tif
#
#
# Exporting 91/240: 90.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/419d5c3b1ac8888cfb02322c2cb02841-39b2147e66d7aba7d474f5decde1338d:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\90.tif
#
#
# Exporting 92/240: 91.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8335edff9c60728ea147c023090d97d9-c38a9cdadd829b582a36b16c8ef49c27:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\91.tif
#
#
# Exporting 93/240: 92.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d94469d5d283834d187f568306af6c36-f65a7273fd8f3046d289358a59462bf5:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\92.tif
#
#
# Exporting 94/240: 93.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/433a551a9d7f2fe7a4d27bc1dea7f48f-72628eac625be4260dca358cfd477816:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\93.tif
#
#
# Exporting 95/240: 94.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/aa67be9553a22473b195406d74f73f38-36c19339e6fd982566d7a44ef5352ae7:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\94.tif
#
#
# Exporting 96/240: 95.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8ccc46c24c935576f64aa6d825666675-65574908ffd26897df1536076917ed0e:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\95.tif
#
#
# Exporting 97/240: 96.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/89b3f576ea94a7f33720ee657bc5cc52-bfb642bd7d279461d8b8aec6f3fd01ca:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\96.tif
#
#
# Exporting 98/240: 97.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0632f0a449e840caacfea16d511f3f80-6eb9112fd01b6b5e7a082045912a39f9:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\97.tif
#
#
# Exporting 99/240: 98.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/fd8f8989931634eb8e679dc1e8ed8811-18a6313ab36ef6f5e62d8464d3525975:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\98.tif
#
#
# Exporting 100/240: 99.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5ae24171b180396d179f239ba9d46215-21c9ea046046e384fcacbf3a4486626c:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\99.tif
#
#
# Exporting 101/240: 100.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1803cfeecb2f1a1929747041316381da-123d0f5ef116106ffba5fcbf6613ed9a:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\100.tif
#
#
# Exporting 102/240: 101.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c2ddf96c2f451107e08a34e4df7d3835-5a5a58df659203385c5d965bccb93265:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\101.tif
#
#
# Exporting 103/240: 102.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c87373ccfec1655f5f2051f37bb486cc-5f2d55739c9690f8d1e7132cbd90579c:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\102.tif
#
#
# Exporting 104/240: 103.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ff6608a692542f06a13b30d634d00441-810c16449281876c8b3cdf93e56244e7:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\103.tif
#
#
# Exporting 105/240: 104.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/fd4dab67a6d867ca637af45a3294871a-3b405d12f6dc35ba4754e3aef0a9355c:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\104.tif
#
#
# Exporting 106/240: 105.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/33cb57a51906e41fd5d9a8de5faac07a-992306e704d31d8b514d77dd75ed6d4f:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\105.tif
#
#
# Exporting 107/240: 106.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4e5e423dcaac1b5791b76906d24ecd2e-d32e3e3b06b62e8eb3e1b96cc880ed63:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\106.tif
#
#
# Exporting 108/240: 107.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0919c8e2524309dc16ee8e04248a42d4-167c893996a4627c7e7ab14b66061018:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\107.tif
#
#
# Exporting 109/240: 108.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/eaa259f8591ea6ee3774c75286e9f1a2-7f4e02fc26f6f2b304460b94940a63c3:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\108.tif
#
#
# Exporting 110/240: 109.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0c286e51620ed9357f843d332e7f5ce5-d74a0d76fae3cfde5bc35d6fa749e26c:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\109.tif
#
#
# Exporting 111/240: 110.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b7144f54d842161c2a793b64df9f4a3d-69a2e7810c4507af61138c54b1ecf5ae:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\110.tif
#
#
# Exporting 112/240: 111.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5d1512b1aad5eb3b7dcec6dd0be5c4f8-781b6c7f76449b9ba1b00207b4589e74:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\111.tif
#
#
# Exporting 113/240: 112.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/dd73fcddaf2c97175473da0089ae03e3-d72a0a829d9fec1cc71d52eba1eb7f13:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\112.tif
#
#
# Exporting 114/240: 113.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5446c3563e926e0fb6641a0486ccf5cf-379361c4cf558ebf1d0f902f872c6677:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\113.tif
#
#
# Exporting 115/240: 114.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/298ca70da2d72fc2352421cefa9e5208-1ff701f62c0c0811dc7ad8d23e4e1915:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\114.tif
#
#
# Exporting 116/240: 115.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/20a2615fb788165d9842fed38cb9963d-ea2e792b72e7362131fc5c68bda9ca8e:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\115.tif
#
#
# Exporting 117/240: 116.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/115e3bc8617fd31ff59de0c38c32560c-027b6927180c4caca7f2761db3ffd94b:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\116.tif
#
#
# Exporting 118/240: 117.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9ef15fc0217cd822e1d00ad06bd55a67-88b04f03538ffd869860668705e5bcef:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\117.tif
#
#
# Exporting 119/240: 118.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8024118d7f7f1cb94e4c234873551c85-e62a8e15f335cfefcc1008cb689410b0:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\118.tif
#
#
# Exporting 120/240: 119.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/cebb108c0e530b60a69c0ca32600366d-3f69e7251876df2e877844c76d2ff9aa:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\119.tif
#
#
# Exporting 121/240: 120.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e2ec430ce96804806ac1e844732e92c1-febf61e93bc796be3ae1005810cd93d9:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\120.tif
#
#
# Exporting 122/240: 121.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/91dfa0ef20577d0a34dd82bfc3868d8e-cbaac87f36c92dc7ace2f32f0eef7f00:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\121.tif
#
#
# Exporting 123/240: 122.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/31bc688b5dda466a551a45bd8f7d306e-d2706054fa70896690e275b68f569fce:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\122.tif
#
#
# Exporting 124/240: 123.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/02d81ab00589279c98e4d73ad00b776a-4515d36e498a85894b445ce4bc6bc261:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\123.tif
#
#
# Exporting 125/240: 124.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/004ae7327ea274cb844cdb5fda3a1e3b-3d7e59ebe8f0ed3f2e14a79dd1d30352:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\124.tif
#
#
# Exporting 126/240: 125.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9497da2f9aaeb062b89208c45dea9695-9cce26e1b46c7ba914d8263080fb4a21:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\125.tif
#
#
# Exporting 127/240: 126.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0c5007b1d79e4d940f27f874e338b66b-af6fba4dc17ed4c7f04fba0ade70e611:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\126.tif
#
#
# Exporting 128/240: 127.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0e061888712d055b875472dad7c91022-244d219f1a19dfb0eaa978c8447ff499:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\127.tif
#
#
# Exporting 129/240: 128.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/22283bec6b5e5561e640937ef921aaa1-6da55f2815df1d7550dbd642986c8d52:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\128.tif
#
#
# Exporting 130/240: 129.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/60dcd26630a193db07f94c79e286d1ce-a43fda1becea2f012bbfea32f11fb098:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\129.tif
#
#
# Exporting 131/240: 130.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/52390e77826cd85179068d6d3dc37623-2406d6e9ebc0ff1de930c2320e8a2992:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\130.tif
#
#
# Exporting 132/240: 131.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d9ebf9c2f382c83c1c96f86fda9ec2a0-e92dde513c7e6a44fb4a87f02e2db419:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\131.tif
#
#
# Exporting 133/240: 132.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/76fab4132098b2cd9fd01f42ca268395-2ab08dacd4731e60824569baefd698a2:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\132.tif
#
#
# Exporting 134/240: 133.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8a900e0766f059a1b931f7891c81dd99-433f36ae419ae6eaf482ec4a355bce16:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\133.tif
#
#
# Exporting 135/240: 134.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d373f831fdf1bb541bfc5ee51fa1f7b6-1c4989cb2ad1fdca3710e2869098523d:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\134.tif
#
#
# Exporting 136/240: 135.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4506e441a377d532659c856f5e127687-216df531650f594db9de62ce255b9921:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\135.tif
#
#
# Exporting 137/240: 136.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7a47fc7553a52f4b6eca426e8f431cfa-50568e9cca247cd7709a7439c8cce4a7:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\136.tif
#
#
# Exporting 138/240: 137.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8aeb38dd6671683361b9d3eed379a112-1e5068490b1e4dfe953821cda1434329:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\137.tif
#
#
# Exporting 139/240: 138.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ac1dc07cd12669128462d5dfc3d46779-ba711a685dc1808dcfae1131e010ce95:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\138.tif
#
#
# Exporting 140/240: 139.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9719843a0699fbe4a790a9e4be0460a8-0b85bd02349bf7faa8e158cfd1c5b7f9:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\139.tif
#
#
# Exporting 141/240: 140.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/84a2143cd2554ba069226d2cc874cd59-ccddd86433c101d9ef6d3694e5c304ba:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\140.tif
#
#
# Exporting 142/240: 141.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5247b9af9cfbd8ec6b3fb229b34087be-3ef231209651c76f4d8c9fb4b4ad3c14:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\141.tif
#
#
# Exporting 143/240: 142.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/552d4047935b69586e3b337a8efd3f86-a36fa0d08c710f89235d4958ceb68eaf:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\142.tif
#
#
# Exporting 144/240: 143.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5607d51ff51680ba9b259d68286d9a26-c219bbfd414a7e0f5545bcb06e517d87:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\143.tif
#
#
# Exporting 145/240: 144.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/fbcae00ad07934e86feea03dca2904ca-d5d07d5b22c7a6b6ebeae3b5a905e27c:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\144.tif
#
#
# Exporting 146/240: 145.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c4ac944bd422693be612b98faba5be90-cd36febb29c19bf7bcfc9faba0abfd6d:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\145.tif
#
#
# Exporting 147/240: 146.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/38c4fa09193836606efa78e0aceeec04-21ff71fa43410454b663642bd9c5b0c5:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\146.tif
#
#
# Exporting 148/240: 147.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/bf65773bbda91adeea46f828f29e67f8-f810bc40cfb04ef8753e2ffe5a259dcc:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\147.tif
#
#
# Exporting 149/240: 148.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/12d92afd3b2ba57b375b367a4f19e8c5-a81016d572a49611a15f0ab211363ce5:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\148.tif
#
#
# Exporting 150/240: 149.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5a58b715b62623d84627a721ce5fc24f-52e7dbc68a363f88473de8121eb5e739:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\149.tif
#
#
# Exporting 151/240: 150.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/004836bb1eca4c1212dbb275c0c57ab2-25bb5754af19cd78f1b625bcac1426d7:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\150.tif
#
#
# Exporting 152/240: 151.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a873a7d1c445b1b7c067bd1eb62d6552-4ed8b29af0048a597e31bc603c00ef8e:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\151.tif
#
#
# Exporting 153/240: 152.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/08e7e758176cc2673dc44fe777f6f32f-1f5520d26ae0ca6481eb25fd01be3879:getPixels
# Please wait ...
# ...
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\189.tif
#
#
# Exporting 191/240: 190.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4743a00a199119fcd7d4fb3d1c26c036-560dfc1fc60f30314212294d22aaac4f:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\190.tif
#
#
# Exporting 192/240: 191.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/156dd97ca1119507a27dabcf3e633ec0-1f24f4bc6f1cd295ac3f54acc02fe8bf:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\191.tif
#
#
# Exporting 193/240: 192.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5061a819d877dbc9b56507c2415fc9df-d0dd62cf1344b922b8a32b7f23ed2a49:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\192.tif
#
#
# Exporting 194/240: 193.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0b50ffe9767ac8a4a0c280de478a0db6-c32b5c1371bd42bfb19283e7871df087:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\193.tif
#
#
# Exporting 195/240: 194.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ee1d1a0e9332b7309965051468ed1036-b94ad2d63d88196186d3e0cde637ea91:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\194.tif
#
#
# Exporting 196/240: 195.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c036b7d8bd74d31e319e5b81a577cb8f-bd811d8528e755362c19fdea1d0b86ed:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\195.tif
#
#
# Exporting 197/240: 196.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/00a2c2c40bfe53f50d21804fb98894e5-042f5319152e6f3448aed103719c30bf:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\196.tif
#
#
# Exporting 198/240: 197.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/da9d658baefaccf390275527b7823cfd-15b4421096296f35358255eceb9be468:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\197.tif
#
#
# Exporting 199/240: 198.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f1811fda029e460e49c44621f347998a-62ac958927cfd77fb56aaa5f6c8972a5:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\198.tif
#
#
# Exporting 200/240: 199.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/26226bb123482c5afe63a17aadfdef43-0c77b1bf908b8950e6a284bfbb196601:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\199.tif
#
#
# Exporting 201/240: 200.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/35cc3eec4ddfd8443887274ec1986d20-7eb462f4248cf5349145854973a6b77c:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\200.tif
#
#
# Exporting 202/240: 201.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6d6edeb9202d2d9f312eb0f9a4d044ce-11c10e2502a5ed9e51cb33d392cbadb4:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\201.tif
#
#
# Exporting 203/240: 202.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/183d77fbb4472625161219aaeb8b4d86-21141ba1b2ce1057ee158c12fc2109fb:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\202.tif
#
#
# Exporting 204/240: 203.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ce4dd4cf3da947d64a88bc850ae56c21-25efd850c7c3ad40cd1fc4397c4b1fa9:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\203.tif
#
#
# Exporting 205/240: 204.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ca073295661c79b4d92a292b07c79a5b-351b6374979e7736247df3a47dc62386:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\204.tif
#
#
# Exporting 206/240: 205.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/aaf42f5b1cb91cd00858e509163f2c4b-7e41146258d4a093a958d74609cc9705:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\205.tif
#
#
# Exporting 207/240: 206.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ee158e1e8eb2a3304c1e6d2a29e66d10-56dfeb471f571ef3955c2edef13cb5ba:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\206.tif
#
#
# Exporting 208/240: 207.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7055600f42b544dd44a43bbb8f30a732-17007b11b85c951742cce4ac1c61ce26:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\207.tif
#
#
# Exporting 209/240: 208.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e4c9ce8642a9571185f9ce1734c0566e-4b988ab55d654ff559187c86f1aee2ea:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\208.tif
#
#
# Exporting 210/240: 209.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/085045ee4bdffb3927bb0b91bafa640f-cacf403fc0c6546d6ac509f5bd2f7d2d:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\209.tif
#
#
# Exporting 211/240: 210.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/630743184ada8612b84b6bf781dc54dc-565cc903e327f24f8fe62904ed883fea:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\210.tif
#
#
# Exporting 212/240: 211.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5277d7a3ca1847f8f83bf1ff863ce81c-f4c917a83f13eb0da18be5bdfb089f96:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\211.tif
#
#
# Exporting 213/240: 212.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/df9c40e701c09e00ba28b1793c338486-efa1e4ed6cffe81ad0ea64165b10ac91:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\212.tif
#
#
# Exporting 214/240: 213.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/99a6503707a513ed0415b71862459113-d7338820c66e74e4a9442453decccb7c:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\213.tif
#
#
# Exporting 215/240: 214.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/545cdb4e8a8a83130e69f1a349b867fe-129fd74909e407981b92c805105d531c:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\214.tif
#
#
# Exporting 216/240: 215.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e471a8c95e851ccbf66c515eadd2093f-a26627c47f6a09dc7b35ad7091a02c7a:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\215.tif
#
#
# Exporting 217/240: 216.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/98726fc6dfba435a03a89d7d9fa11ca0-85f07d04bbbbf5256e67bc78cece4252:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\216.tif
#
#
# Exporting 218/240: 217.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/44ecda7a41bcc25da2880fcc6f5c96af-d935d7a514918cdfa2065a5de9f62be4:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\217.tif
#
#
# Exporting 219/240: 218.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/fa19f4ec3e32e91180ffcbc18c67c017-3c56e1951125347df2201289f8b9003a:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\218.tif
#
#
# Exporting 220/240: 219.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5c8fe62b536178feff41465797d939d5-16d1a283ca426fefe39ed13b82cc1312:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\219.tif
#
#
# Exporting 221/240: 220.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4bd42d0f3220c690eeb93cc2f1ddbdfa-5090c6219053efa813fb7e6655547e72:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\220.tif
#
#
# Exporting 222/240: 221.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/750f85115a0301dedfcacb9ea6ae604b-4caaebc8a85763b356c32504dd4da402:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\221.tif
#
#
# Exporting 223/240: 222.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/514a85bf20f2baf7988886bcd55b8b5d-1d1e36737c0236bdec57910081434787:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\222.tif
#
#
# Exporting 224/240: 223.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1785fd7571706d7a9ebce6d2e03c838a-72e0cf6520f6363380e57151b5faee88:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\223.tif
#
#
# Exporting 225/240: 224.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/be34f115eecba1b388f4f9403e74f739-1d234e18041610411f6becd9f4faa62b:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\224.tif
#
#
# Exporting 226/240: 225.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7bed55882cef9c18c98adf0db6256278-448fbb05cbb54186ddbe90a3d27f7fd5:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\225.tif
#
#
# Exporting 227/240: 226.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/39574373ab99e1511edf8195349b8e0a-2b24fdd688b9af74e299ab11d387969c:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\226.tif
#
#
# Exporting 228/240: 227.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/048039c333b3861a331377e9c3f2fc66-f788fccf5283484f227d306fac2c2530:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\227.tif
#
#
# Exporting 229/240: 228.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3dd2937628bae64404064c7f7002a0b1-3355cea40183b690f5cc6f4e4fb70150:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\228.tif
#
#
# Exporting 230/240: 229.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/35c15a70d56403a67ee3a9c951b092e1-43019b691cf0e8e137df9be9791fbdea:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\229.tif
#
#
# Exporting 231/240: 230.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/34b06d5e94a5c2892cbc6fbdd5e79f2f-ccc855a1f1f4583e6d470348e75a0a9b:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\230.tif
#
#
# Exporting 232/240: 231.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b10e340fc728e74227a0cd5e1d71aa50-fb4426233bcc49a489cc9d15c96b7b58:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\231.tif
#
#
# Exporting 233/240: 232.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/fe902219c9830191881a2c43e4c267a1-112a53bdd64944e048d5cdcda212a525:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\232.tif
#
#
# Exporting 234/240: 233.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8cc48703a60770735ef239e989b33f65-bff0b9d9b43eb8a08a25eb21d1256a7e:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\233.tif
#
#
# Exporting 235/240: 234.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e0829950bf6a16206a6ae3ea27e809fe-2cb587756a8f51432ee438587344af48:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\234.tif
#
#
# Exporting 236/240: 235.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/dc9ee83f0e975799c24569e16d110e1f-d0f39e2157103b5959e98ba31740a1f6:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\235.tif
#
#
# Exporting 237/240: 236.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f89ba0784dd47a42af73529480cea97b-ec68c9a073cfd847577b860429aaa098:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\236.tif
#
#
# Exporting 238/240: 237.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f6c44bd41304acdf188efad86ccb3abb-e1d056fe09f9753902a754cc44bfd207:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\237.tif
#
#
# Exporting 239/240: 238.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/91e9851cce35910bab882960930554c1-d6a18856d9753764c297acfa57257fc6:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\238.tif
#
#
# Exporting 240/240: 239.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1d8081b80fc624abfe032ecb10742308-45344ca630253469ffe2228e768abd6d:getPixels
# Please wait ...
# Data downloaded to C:\Users\Mukesh\Downloads\ndvi_stack16_terra\239.tif
